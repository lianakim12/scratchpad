# %% [markdown]
# <a href="https://colab.research.google.com/github/ds4e/scratchpad/blob/main/nb_20260122_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ds4e/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 82 (delta 31), reused 21 (delta 8), pack-reused 24 (from 2)
# Receiving objects: 100% (82/82), 77.89 KiB | 3.12 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./data/CardiacPatientData.csv')

df.head()
# Out:
#    ID  SBP  DBP  HR  RR  BT  SpO2  Age  Gender  GCS     Na    K     Cl  Urea  \
# 0   1  163   95  90  18  98    98   66       1   15  139.0  4.0  105.0  41.0
# 1   1  134   85  85  15  98    98   66       1   15  139.0  4.0  105.0  41.0
# 2   1  121   77  80  19  98    98   66       1   15  139.0  4.0  105.0  41.0
# 3   1  103   78  70  16  98    98   66       1   15  139.0  4.0  105.0  41.0
# 4   1   96   70  59  13  98    98   66       1   15  139.0  4.0  105.0  41.0
#
#    Ceratinine  Alcoholic  Smoke  FHCD  TriageScore  Outcome
# 0        91.0        1.0    1.0   0.0          3.0        1
# 1        91.0        1.0    1.0   0.0          3.0        1
# 2        91.0        1.0    1.0   0.0          3.0        1
# 3        91.0        1.0    1.0   0.0          3.0        1
# 4        91.0        1.0    1.0   0.0          3.0        1

# %%
df.shape
# Out:
# (5906, 20)

# %%
df['Age'].describe()
# Out:
# count    5906.000000
# mean       59.677955
# std        15.686047
# min        15.000000
# 25%        51.000000
# 50%        61.000000
# 75%        71.000000
# max        89.000000
# Name: Age, dtype: float64

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
df = pd.read_csv('./data/craigslist_cville_cars.csv')
df.head()
# Out:
#    Unnamed: 0                                              title  price  \
# 0           0                      a sweet sedan avalon xle plus  24000
# 1           1  1998 gmc sierra 1500 sl truck auto rwd <103,00...   6950
# 2           2        gmc sierra 3500hd 6.6 duramax diesel dually  26000
# 3           3                              2007 chrysler sebring   2900
# 4           4                               2012 nissan versa sl   3500
#
#      year                                               link    brand   age
# 0     NaN  https://charlottesville.craigslist.org/cto/d/c...  missing   NaN
# 1  1998.0  https://charlottesville.craigslist.org/cto/d/l...      gmc  27.0
# 2     NaN  https://charlottesville.craigslist.org/cto/d/c...      gmc   NaN
# 3  2007.0  https://charlottesville.craigslist.org/cto/d/c...  missing  18.0
# 4  2012.0  https://charlottesville.craigslist.org/cto/d/c...  missing  13.0

# %%
df['year'].describe()
# Out:
# count      41.000000
# mean     2000.878049
# std        16.315936
# min      1957.000000
# 25%      1994.000000
# 50%      2006.000000
# 75%      2012.000000
# max      2019.000000
# Name: year, dtype: float64

# %%
df.shape
# Out:
# (46, 7)

# %%
df['year_na'] = df['year'].isna()
imp_value = df['year'].median()

df['year_imp'] = df['year'].fillna(imp_value)

# %%
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# Name: year, dtype: bool

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  price  \
# 0           0                      a sweet sedan avalon xle plus  24000
# 1           1  1998 gmc sierra 1500 sl truck auto rwd <103,00...   6950
# 2           2        gmc sierra 3500hd 6.6 duramax diesel dually  26000
# 3           3                              2007 chrysler sebring   2900
# 4           4                               2012 nissan versa sl   3500
#
#      year                                               link    brand   age  \
# 0     NaN  https://charlottesville.craigslist.org/cto/d/c...  missing   NaN
# 1  1998.0  https://charlottesville.craigslist.org/cto/d/l...      gmc  27.0
# 2     NaN  https://charlottesville.craigslist.org/cto/d/c...      gmc   NaN
# 3  2007.0  https://charlottesville.craigslist.org/cto/d/c...  missing  18.0
# 4  2012.0  https://charlottesville.craigslist.org/cto/d/c...  missing  13.0
#
#    year_na  year_imp
# 0     True    2006.0
# 1    False    1998.0
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# missing       14
# honda          5
# chevrolet      4
# toyota         4
# ford           3
# chevy          3
# bmw            3
# jeep           2
# gmc            2
# lexus          2
# subaru         1
# dodge          1
# mitsubishi     1
# audi           1
# Name: count, dtype: int64

# %%
df.loc[ df['brand'] == 'honda', : ]
# Out:
#     Unnamed: 0                                           title  price    year  \
# 23          23                             2012 honda civic lx   5900  2012.0
# 33          33                        2006 honda pilot exl fwd   4700  2006.0
# 41          41                               2010 honda crv lx   6500  2010.0
# 43          43  sold haters  1992 honda accord gas sipper sold   2300  1992.0
# 45          45                                  2015 honda fit   8749  2015.0
#
#                                                  link  brand   age  year_na  \
# 23  https://charlottesville.craigslist.org/cto/d/h...  honda  13.0    False
# 33  https://charlottesville.craigslist.org/cto/d/h...  honda  19.0    False
# 41  https://charlottesville.craigslist.org/cto/d/h...  honda  15.0    False
# 43  https://charlottesville.craigslist.org/cto/d/c...  honda  33.0    False
# 45  https://charlottesville.craigslist.org/cto/d/c...  honda  10.0    False
#
#     year_imp
# 23    2012.0
# ...

# %%
import seaborn as sns

sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df  = pd.read_csv('./data/airbnb_hw.csv')
df.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
df['Review Scores Rating'].value_counts()
# Out:
# Review Scores Rating
# 100.0    5594
# 90.0     1729
# 93.0     1614
# 80.0     1423
# 95.0     1295
# 96.0     1188
# 97.0     1033
# 94.0      943
# 92.0      875
# 98.0      843
# 91.0      812
# 87.0      714
# 88.0      614
# 89.0      561
# 85.0      365
# 86.0      348
# 99.0      318
# 84.0      289
# 83.0      267
# 60.0      244
# 82.0      136
# 70.0      132
# 73.0       89
# 78.0       84
# 77.0       80
# 76.0       75
# 81.0       66
# 75.0       60
# 40.0       47
# 79.0       46
# 67.0       42
# 20.0       39
# 72.0       32
# 74.0       26
# 71.0       22
# 65.0       21
# 68.0       19
# 50.0       19
# 69.0       11
# 53.0        8
# 62.0        5
# 63.0        5
# 64.0        4
# 66.0        3
# 47.0        3
# 55.0        3
# 57.0        2
# 58.0        2
# 43.0        2
# 30.0        2
# 49.0        1
# Name: count, dtype: int64

# %%
sns.histplot(df['Review Scores Rating'])
# Out:
# <Axes: xlabel='Review Scores Rating', ylabel='Count'>

# %%
np.sum(df.isna())
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8323
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8323
# dtype: int64

# %%
df.shape
# Out:
# (30478, 14)

# %%
med = df['Review Scores Rating'].median()
df['review_imp'] = df['Review Scores Rating'].fillna(med)

# %%
sns.kdeplot(df['review_imp'])
# Out:
# <Axes: xlabel='review_imp', ylabel='Density'>

# %%
sns.kdeplot(df['Review Scores Rating'])
# Out:
# <Axes: xlabel='Review Scores Rating', ylabel='Density'>

# %%
med
# Out:
# 94.0

# %%
df['Price'].unique()
# Out:
# array(['145', '37', '28', '199', '549', '149', '250', '90', '270', '290',
#        '170', '59', '49', '68', '285', '75', '100', '150', '700', '125',
#        '175', '40', '89', '95', '99', '499', '120', '79', '110', '180',
#        '143', '230', '350', '135', '85', '60', '70', '55', '44', '200',
#        '165', '115', '74', '84', '129', '50', '185', '80', '190', '140',
#        '45', '65', '225', '600', '109', '1,990', '73', '240', '72', '105',
#        '155', '160', '42', '132', '117', '295', '280', '159', '107', '69',
#        '239', '220', '399', '130', '375', '585', '275', '139', '260',
#        '35', '133', '300', '289', '179', '98', '195', '29', '27', '39',
#        '249', '192', '142', '169', '1,000', '131', '138', '113', '122',
#        '329', '101', '475', '238', '272', '308', '126', '235', '315',
#        '248', '128', '56', '207', '450', '215', '210', '385', '445',
#        '136', '247', '118', '77', '76', '92', '198', '205', '299', '222',
# ...

# %%
x = df['Price'].str.replace(',' , '')
x = pd.to_numeric( x, errors='coerce')

# %%
sns.histplot(x)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
import numpy as np

y = np.log(x)

sns.histplot(y)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.kdeplot(y)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>
